# %% [markdown]
# ##### Dataset - https://www.kaggle.com/datasets/iamsouravbanerjee/customer-shopping-trends-dataset?select=shopping_trends.csv

# %% [markdown]
#  ###  Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
colors = ["#89CFF0", "#FF69B4", "#FFD700", "#7B68EE", "#FF4500",
          "#9370DB", "#32CD32", "#8A2BE2", "#FF6347", "#20B2AA",
          "#FF69B4", "#00CED1", "#FF7F50", "#7FFF00", "#DA70D6"]

# %% [markdown]
# ### Reading the dataset

# %%
df=pd.read_csv('./data_sets/shopping_trends.csv')

# %% [markdown]
# ### Customer ID: Unique identifier for each customer
#
# Age: Age of the customer
#
# Gender: Gender of the customer (Male/Female)
#
# Item Purchased: The item purchased by the customer
#
# Category: Category of the item purchased
#
# Purchase Amount (USD): The amount of the purchase in USD
#
# Location: Location where the purchase was made
# Size: Size of the purchased item
#
# Color: Color of the purchased item
#
# Season: Season during which the purchase was made
#
# Review Rating: Rating given by the customer for the purchased item
#
# Subscription Status: Indicates if the customer has a subscription (Yes/No)
#
# Shipping Type: Type of shipping chosen by the customer
#
# Discount Applied: Indicates if a discount was applied to the purchase (Yes/No)
#
# Promo Code Used: Indicates if a promo code was used for the purchase (Yes/No)
#
# Previous Purchases: The total count of transactions concluded by the customer at the store, excluding
# the ongoing transaction
#
# Payment Method: Customer's most preferred payment method
#
# Frequency of Purchases: Frequency at which the customer makes purchases (e.g., Weekly, Fortnightly,
# Monthly)

# %% [markdown]
# ##  Exploratry Data Analysis

# %% [markdown]
# #### Display top 5 rows of the dataset

# %%
df['age bins']=pd.cut(df['Age'],bins=[17,25,35,55,70],labels =['youth','mid adult','adult','senior adult'])

# %%
import numpy as np
import pandas as pd

# Assuming df is your DataFrame

# Replace 'Purchase Amount (USD)' and 'price' with the actual column names from your DataFrame
bins = np.linspace(min(df['Purchase Amount (USD)']), max(df['Purchase Amount (USD)']), 4)
group_names = ["Low", "Medium", "High"]

# Assuming you want to create a new column named 'price-binned'
df["price-binned"] = pd.cut(df['Purchase Amount (USD)'], bins, labels=group_names, include_lowest=True)

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  ...  Subscription Status  \
# 0       Kentucky    L       Gray  Winter  ...                  Yes
# 1          Maine    L     Maroon  Winter  ...                  Yes
# 2  Massachusetts    S     Maroon  Spring  ...                  Yes
# 3   Rhode Island    M     Maroon  Spring  ...                  Yes
# 4         Oregon    M  Turquoise  Spring  ...                  Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# ...

# %% [markdown]
# #### Display last 5 rows of the dataset

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  ...  \
# 3895                     28    Virginia    L  Turquoise  Summer  ...
# 3896                     49        Iowa    L      White  Spring  ...
# 3897                     33  New Jersey    L      Green  Spring  ...
# 3898                     77   Minnesota    S      Brown  Summer  ...
# 3899                     81  California    M      Beige  Spring  ...
#
#       Subscription Status Payment Method   Shipping Type Discount Applied  \
# 3895                   No           Cash  2-Day Shipping               No
# ...

# %% [markdown]
# #### Print Random 5 rows of dataset

# %%
df.sample(5)
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 3411         3412   29  Female          Shoes   Footwear
# 3692         3693   59  Female           Coat  Outerwear
# 373           374   23    Male           Coat  Outerwear
# 3480         3481   21  Female        Sandals   Footwear
# 3629         3630   52  Female        T-shirt   Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 3411                     56       New York    L       Gray  Winter  ...
# 3692                     34        Alabama    L  Turquoise  Spring  ...
# 373                      27   North Dakota    L      White  Summer  ...
# 3480                     79  New Hampshire    L      Peach  Winter  ...
# 3629                     43         Kansas    L   Lavender  Summer  ...
#
#       Subscription Status Payment Method   Shipping Type Discount Applied  \
# 3411                   No          Venmo  2-Day Shipping               No
# ...

# %% [markdown]
# ####  Columns in the dataset

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %% [markdown]
# #### Find shape of dataset

# %%
df.shape
# Out:
# (3900, 21)

# %% [markdown]
# #### Check Missing Values In The Dataset

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# age bins                    0
# price-binned                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #### Get overall ststistics about datasets

# %%
pd.options.display.float_format ='{:.2f}'.format

# %%
df.describe()
# Out:
#        Customer ID     Age  Purchase Amount (USD)  Review Rating  \
# count      3900.00 3900.00                3900.00        3900.00
# mean       1950.50   44.07                  59.76           3.75
# std        1125.98   15.21                  23.69           0.72
# min           1.00   18.00                  20.00           2.50
# 25%         975.75   31.00                  39.00           3.10
# 50%        1950.50   44.00                  60.00           3.70
# 75%        2925.25   57.00                  81.00           4.40
# max        3900.00   70.00                 100.00           5.00
#
#        Previous Purchases
# count             3900.00
# mean                25.35
# std                 14.45
# min                  1.00
# 25%                 13.00
# 50%                 25.00
# 75%                 38.00
# max                 50.00

# %% [markdown]
# #### Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %% [markdown]
# ## Descriptive Analytics Questions:

# %% [markdown]
# #### What is the overall distribution of customer ages in the dataset?

# %%
plt.hist(df['Age'], bins=25, edgecolor='k',)
plt.title("Ditistribution of Customer Age")
plt.ylabel("Number of Customer")
plt.xlabel('Age')
plt.show()

# %% [markdown]
# #### What is the gender distribution of customers in the dataset?

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='Gender',data=df,width=0.5)
plt.title('Distribution Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# #### What are the most frequently purchased items (top products) in the dataset?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
sns.countplot(y='Item Purchased',data=df)
plt.grid()
plt.title(' Product  Purchased ');

# %%
df['Item Purchased'].value_counts().sort_values(ascending=False).head().plot(kind='bar',color=('blue','red','green','orange','brown'))
plt.title('Top 5 Most Purchased Products')
plt.xlabel("Item Purchased")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### How are the purchases distributed across different categories of items (e.g., clothing, accessories, shoes)?

# %%
sns.countplot(x='Category',data=df)
plt.title('Purchases based on Category ')
plt.show()

# %% [markdown]
# #### What is the average purchase amount in USD, and how does it vary across different categories of items?

# %%
df.groupby('Category')['Purchase Amount (USD)'].mean()
# Out:
# Category
# Accessories   59.84
# Clothing      60.03
# Footwear      60.26
# Outerwear     57.17
# Name: Purchase Amount (USD), dtype: float64

# %%
sns.barplot(x='Category',y='Purchase Amount (USD)',data=df)
plt.grid()

# %% [markdown]
# #### What are the most popular sizes and colors for purchased items?

# %%
df['Color'].value_counts().sort_values(ascending=False).head(10).plot(kind="bar",color=['olive','yellow','silver','Teal','green','black','cyan','violet','grey','maroon'])
plt.title("The Top Ten Colors of purchased items")
plt.xlabel("Colors")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Can you identify any seasonal shopping trends based on the "Season" column?

# %%
df['Season'].value_counts().plot()
plt.title('Purchased Items by Season')
plt.xlabel("Season")
plt.ylabel('Count');

# %% [markdown]
# #### What is the distribution of review ratings given by customers?

# %%
sns.histplot(df['Review Rating'],bins=20)
plt.figure(figsize=(20,5))

# %% [markdown]
# #### What percentage of customers have a subscription, and does subscription status impact purchase behavior?

# %%
no_of_subscribers=(df['Subscription Status']=='Yes').sum()
Total_no_of_customers=len(df)
percentage_of_subscribers=(no_of_subscribers*100)/Total_no_of_customers
print('Subscribers percentage =',percentage_of_subscribers,'%')
# Out:
# Subscribers percentage = 27.0 %

# %%
sns.scatterplot(y='Purchase Amount (USD)',x='Subscription Status',data=df)
# Out:
# <Axes: xlabel='Subscription Status', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# #### What are the preferred shipping types among customers, and do they correlate with the purchase amount or frequency?

# %%
df['Shipping Type'].unique()
# Out:
# array(['Express', 'Free Shipping', 'Next Day Air', 'Standard',
#        '2-Day Shipping', 'Store Pickup'], dtype=object)

# %%
df.groupby('Shipping Type')['Purchase Amount (USD)'].sum().sort_values(ascending=False).plot(kind='bar',color=colors)
# Out:
# <Axes: xlabel='Shipping Type'>

# %%
df.groupby('Shipping Type')['Frequency of Purchases'].value_counts()
# Out:
# Shipping Type   Frequency of Purchases
# 2-Day Shipping  Every 3 Months             97
#                 Monthly                    95
#                 Quarterly                  93
#                 Fortnightly                89
#                 Bi-Weekly                  87
#                 Annually                   84
#                 Weekly                     82
# Express         Bi-Weekly                 100
#                 Every 3 Months             99
#                 Annually                   96
#                 Weekly                     94
#                 Fortnightly                88
#                 Quarterly                  85
#                 Monthly                    84
# Free Shipping   Annually                  112
#                 Weekly                    110
#                 Quarterly                 101
#                 Every 3 Months            101
#                 Monthly                    90
# ...

# %%
sns.scatterplot(x='Frequency of Purchases',y='Shipping Type',data=df)
# Out:
# <Axes: xlabel='Frequency of Purchases', ylabel='Shipping Type'>

# %% [markdown]
# #### How frequently are discounts applied, and does this impact the purchase amount?

# %%
sns.countplot(x='Discount Applied',data=df)
plt.title('Discounts')
# Out:
# Text(0.5, 1.0, 'Discounts')

# %%
sns.barplot(x='Discount Applied',y='Purchase Amount (USD)',data=df)
# Out:
# <Axes: xlabel='Discount Applied', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# #### How often do customers use promo codes, and does it vary by gender or age group?

# %%
sns.countplot(x='Promo Code Used',data=df)
plt.title('Promo code users')
# Out:
# Text(0.5, 1.0, 'Promo code users')

# %%
sns.countplot(x='Promo Code Used',data=df,hue='Gender')
plt.title('Promo code user based on gneder')
# Out:
# Text(0.5, 1.0, 'Promo code user based on gneder')

# %% [markdown]
# #### Diagnostic Analytics Questions:

# %% [markdown]
# #### Is there a correlation between the number of previous purchases and the purchase amount for individual customers?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
sns.scatterplot(x='Previous Purchases',y='Purchase Amount (USD)',data=df)
# Out:
# <Axes: xlabel='Previous Purchases', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# #### Are there any significant differences in purchase behavior between male and female customers?

# %%
sns.barplot(x='Gender',y='Previous Purchases',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Previous Purchases'>

# %% [markdown]
# #### Does the choice of payment method affect the purchase amount or frequency of purchases?

# %%
sns.scatterplot(x='Payment Method',y='Frequency of Purchases',data=df)
# Out:
# <Axes: xlabel='Payment Method', ylabel='Frequency of Purchases'>

# %% [markdown]
# #### Can you identify any patterns in the frequency of purchases (e.g., weekly, fortnightly, monthly) and how they relate to other variables like age or gender?

# %%
sns.lineplot(x='Frequency of Purchases',y='Age',data=df,hue='Gender')
plt.title('Frequency of Purchases based on Gender')
# Out:
# Text(0.5, 1.0, 'Frequency of Purchases based on Gender')

# %% [markdown]
# #### Are there specific categories or items that are more likely to lead to high or low review ratings?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
df.groupby("Category")['Review Rating'].mean()
# Out:
# Category
# Accessories   3.77
# Clothing      3.72
# Footwear      3.79
# Outerwear     3.75
# Name: Review Rating, dtype: float64

# %%
sns.barplot(x='Category',y='Review Rating',data= df)
plt.figure(figsize=(10,3))

# %% [markdown]
# #### Is there a relationship between having a subscription and making more frequent purchases?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
df.groupby('Frequency of Purchases')['Subscription Status'].value_counts().plot(kind='bar',color=colors)
# Out:
# <Axes: xlabel='Frequency of Purchases,Subscription Status'>

# %% [markdown]
# #### Does the choice of shipping type impact the purchase amount, and are there geographical variations in shipping preferences?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
sns.barplot(x='Shipping Type', y='Purchase Amount (USD)', data=df)
plt.title('Purchase Amount by Shipping Type')
plt.xticks(rotation =90)
plt.xlabel('Purchase Amount (USD)')
plt.ylabel('Shipping Type')
plt.figure(figsize=(10,3))

plt.show()

# %% [markdown]
# #### Are there any interesting insights related to the use of promo codes, such as which customer segments use them more frequently?

# %%
plt.title('Frequency of Purchases vs Promo Code Used ')
sns.countplot(x='Frequency of Purchases',hue='Promo Code Used',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Promo Code Used',data=df,hue="Gender")
# Out:
# <Axes: xlabel='Promo Code Used', ylabel='count'>

# %% [markdown]
# #### How do items with discounts applied compare to those without in terms of purchase amount and frequency?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
df.groupby('Discount Applied')['Purchase Amount (USD)'].sum().plot(kind='pie')
plt.show()
df.groupby('Discount Applied')['Purchase Amount (USD)'].mean()
# Out:
# Discount Applied
# No    60.13
# Yes   59.28
# Name: Purchase Amount (USD), dtype: float64

# %%
df.pivot_table(index ="Discount Applied",values='Purchase Amount (USD)',aggfunc=['mean','sum'])
df.pivot_table(index ="Frequency of Purchases",values='Purchase Amount (USD)',aggfunc=['mean','sum'])
df.pivot_table(index =["Frequency of Purchases","Discount Applied"],values='Purchase Amount (USD)',aggfunc=['mean','sum'])
# Out:
#                                                          mean  \
#                                         Purchase Amount (USD)
# Frequency of Purchases Discount Applied
# Annually               No                               60.67
#                        Yes                              59.47
# Bi-Weekly              No                               60.53
#                        Yes                              60.92
# Every 3 Months         No                               60.69
#                        Yes                              59.32
# Fortnightly            No                               59.63
#                        Yes                              58.34
# Monthly                No                               59.53
#                        Yes                              59.07
# Quarterly              No                               60.21
#                        Yes                              59.68
# ...

# %% [markdown]
# ### Descriptive Analytics Questions for Business Improvement:

# %% [markdown]
# #### What is the average purchase amount (in USD) per customer, and how can it be increased?

# %%
mean_purchse_amount=df.groupby('Customer ID')['Purchase Amount (USD)'].mean()
mean_purchse_amount=mean_purchse_amount.astype(int)
mean_purchse_amount
# Out:
# Customer ID
# 1       53
# 2       64
# 3       73
# 4       90
# 5       49
#         ..
# 3896    28
# 3897    49
# 3898    33
# 3899    77
# 3900    81
# Name: Purchase Amount (USD), Length: 3900, dtype: int32

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %% [markdown]
# #### Can we identify the most profitable categories and items, and should we focus more on promoting them?

# %%
df.groupby('Category')['Purchase Amount (USD)'].sum().plot(kind='pie')
plt.ylabel('')
plt.title("Most Profitable Categories")
# Out:
# Text(0.5, 1.0, 'Most Profitable Categories')

# %%
df.groupby('Item Purchased')['Purchase Amount (USD)'].sum().sort_values(ascending=False).plot(kind='bar',color=colors)
plt.title("Most Profitable Items")
plt.ylabel('Purchase Amount (USD)')
# Out:
# Text(0, 0.5, 'Purchase Amount (USD)')

# %% [markdown]
# #### What are the key demographics (age and gender) of our most frequent and high-spending customers, and how can we target similar customers?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
df.pivot_table(index=['Gender','Frequency of Purchases'],values=['Purchase Amount (USD)'],aggfunc='sum')
# Out:
#                                Purchase Amount (USD)
# Gender Frequency of Purchases
# Female Annually                                11136
#        Bi-Weekly                               11264
#        Every 3 Months                          11562
#        Fortnightly                              9637
#        Monthly                                 11088
#        Quarterly                               10468
#        Weekly                                  10036
# Male   Annually                                23283
#        Bi-Weekly                               21936
#        Every 3 Months                          23526
#        Fortnightly                             22370
#        Monthly                                 21722
#        Quarterly                               23303
#        Weekly                                  21750

# %%
df.pivot_table(index=['Gender','Frequency of Purchases'],values=['Purchase Amount (USD)','Age'],aggfunc='mean')
# Out:
#                                 Age  Purchase Amount (USD)
# Gender Frequency of Purchases
# Female Annually               45.24                  60.19
#        Bi-Weekly              42.61                  59.91
#        Every 3 Months         43.53                  62.16
#        Fortnightly            42.97                  59.12
#        Monthly                45.44                  59.94
#        Quarterly              43.04                  61.94
#        Weekly                 45.12                  58.35
# Male   Annually               44.39                  60.16
#        Bi-Weekly              43.51                  61.10
#        Every 3 Months         43.35                  59.11
#        Fortnightly            43.85                  59.02
#        Monthly                43.70                  59.03
#        Quarterly              45.39                  59.14
#        Weekly                 44.43                  59.26

# %% [markdown]
# #### What are the key demographics (age and gender) of our most frequent and high-spending customers, and how can we target similar customers?

# %%
df.groupby('age bins')['Purchase Amount (USD)'].sum().nlargest(10).plot(kind='bar')
# Out:
# <Axes: xlabel='age bins'>

# %% [markdown]
# #### Where should we consider opening new store locations based on the popular purchase locations?

# %%
df.groupby("Location")['Purchase Amount (USD)'].sum().nlargest(5).plot(kind='bar')
plt.ylabel('Purchase Amount (USD)')
plt.title(' Top 5 location based on Purchases')
# Out:
# Text(0.5, 1.0, ' Top 5 location based on Purchases')

# %% [markdown]
# #### Are there particular seasons when sales are significantly higher, and can we leverage this information for marketing and inventory management?

# %%
df.groupby('Season')['Purchase Amount (USD)'].sum().plot(kind='line')
# Out:
# <Axes: xlabel='Season'>

# %% [markdown]
# #### Is there a correlation between review ratings and customer loyalty or repeat purchases?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %% [markdown]
# #### How can we encourage more customers to subscribe to our service, and does subscription status lead to increased spending?

# %% [markdown]
# #### What insights can we gain regarding shipping preferences and how can we optimize our shipping methods for better customer satisfaction?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
df.groupby('Shipping Type')['Purchase Amount (USD)'].sum().nlargest(5).plot(kind='line')
plt.title('Purchase Amount (USD) based on the Shipping type')
plt.show()

# %% [markdown]
# #### Are discounts and promo codes effective in increasing purchase amounts, and can we improve our discount strategy?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
df.groupby('Promo Code Used')['Purchase Amount (USD)'].sum().plot(kind='pie')
plt.ylabel('')
plt.title('Promo code users Purchase amount')
plt.show()

# %%
df.groupby('Discount Applied')['Purchase Amount (USD)'].sum().plot(kind='pie')
plt.ylabel('')
plt.title('Discount Applied  Purchase amount')
plt.show()

# %% [markdown]
# #### How does the choice of payment method impact customer satisfaction and purchase behavior, and should we consider offering more payment options?

# %%
sns.countplot(x='Payment Method',data=df)
plt.xticks(rotation=90)
plt.grid()
plt.title('most used payment method')
plt.show()

# %% [markdown]
# ### Diagnostic Analytics Questions for Business Improvement:

# %% [markdown]
# #### Are there specific categories or items where customer satisfaction tends to be low, and what improvements can be made in these areas?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
df.groupby('Item Purchased')['Review Rating'].mean().nsmallest()
# Out:
# Item Purchased
# Shirt    3.63
# Jeans    3.65
# Blouse   3.68
# Scarf    3.70
# Shorts   3.71
# Name: Review Rating, dtype: float64

# %%
df.groupby('Category')['Review Rating'].mean().nsmallest()
# Out:
# Category
# Clothing      3.72
# Outerwear     3.75
# Accessories   3.77
# Footwear      3.79
# Name: Review Rating, dtype: float64

# %% [markdown]
# #### Can we identify any customer segments with declining or inconsistent purchase frequency, and how can we re-engage them?

# %% [markdown]
# #### What factors contribute to customers not using promo codes, and can we incentivize their use effectively?

# %% [markdown]
# #### Is there a pattern in previous purchase counts that suggests customer churn or decreased loyalty, and what strategies can be implemented to prevent this?

# %% [markdown]
# #### How do location, season, and item categories interact to influence purchase amounts, and can we create targeted marketing campaigns based on these interactions?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
max_purchase_amount_by_location=df.groupby('Location')['Purchase Amount (USD)'].sum().nlargest()
print(max_purchase_amount_by_location)
# Out:
# Location
# Montana       5784
# Illinois      5617
# California    5605
# Idaho         5587
# Nevada        5514
# Name: Purchase Amount (USD), dtype: int64

# %%
min_purchase_amount_by_location=df.groupby('Location')['Purchase Amount (USD)'].sum().nsmallest()
print(min_purchase_amount_by_location)
min_purchase_amount_by_location.plot(kind='bar')
plt.xlabel('country')
plt.ylabel('Purchases amount')
plt.title('Total purchase amount by Country');
# Out:
# Location
# Kansas          3437
# Hawaii          3752
# Florida         3798
# New Jersey      3802
# Rhode Island    3871
# Name: Purchase Amount (USD), dtype: int64

# %%
max_purchase_amount_by_location.plot(kind='bar')
plt.xlabel('country')
plt.ylabel('Purchases amount')
plt.title('Total purchase amount by Country');

# %%
result = df.pivot_table(index=['Location', 'Season'], values='Purchase Amount (USD)', aggfunc=sum)

top_countries = result.groupby('Location')['Purchase Amount (USD)'].sum().nlargest(5).index

top_5_result = result[result.index.get_level_values('Location').isin(top_countries)]
print(top_5_result)
# Out:
#                    Purchase Amount (USD)
# Location   Season
# California Fall                     1659
#            Spring                   1400
#            Summer                   1257
#            Winter                   1289
# Idaho      Fall                     1622
#            Spring                   1525
#            Summer                   1400
#            Winter                   1040
# Illinois   Fall                     1517
#            Spring                   1620
#            Summer                   1220
#            Winter                   1260
# Montana    Fall                     1303
#            Spring                   1324
#            Summer                   1526
#            Winter                   1631
# Nevada     Fall                     1188
#            Spring                   1916
#            Summer                   1478
#            Winter                    932

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
result = df.pivot_table(index=['Location', 'Season'], values='Purchase Amount (USD)', aggfunc=sum)

# Get the top 5 countries by purchase amount
top_countries = result.groupby('Location')['Purchase Amount (USD)'].sum().nlargest(5).index

# Filter the result DataFrame for the top 5 countries
top_5_result = result[result.index.get_level_values('Location').isin(top_countries)]

# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

for country in top_countries:
    country_data = top_5_result.loc[country]
    ax.plot(country_data.index.get_level_values('Season'), country_data['Purchase Amount (USD)'], label=country)

# Customize the plot
ax.set_xlabel('Season')
ax.set_ylabel('Purchase Amount (USD)')
ax.legend()
plt.title('Top 5 Countries by Purchase Amount')
plt.show()

# %% [markdown]
# #### Are there instances where shipping type preferences are leading to order cancellations or dissatisfaction, and how can we address these issues?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %%
df.groupby('Shipping Type')['Review Rating'].mean().sort_values().plot(kind='line')
# Out:
# <Axes: xlabel='Shipping Type'>

# %% [markdown]
# #### Can we use historical data to forecast demand for specific items or categories, helping with inventory management?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %% [markdown]
# #### What insights can be gained from the analysis of payment methods, and can we streamline payment processes to improve the customer experience?

# %%
df.groupby('Payment Method')['Purchase Amount (USD)'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment Method'>

# %% [markdown]
# #### Are there particular age or gender groups that exhibit unusual purchasing patterns, and how can we tailor marketing efforts accordingly?

# %%
df.groupby('age bins')['Category'].value_counts().plot(kind='bar',color=colors)
# Out:
# <Axes: xlabel='age bins,Category'>

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'price-binned'],
#       dtype='object')

# %% [markdown]
# #### How can we create a personalized shopping experience for customers based on their previous interactions with the business?

# %%
df.rename(columns={'price-binned':'Price_bin'},inplace=True)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'Price_bin'],
#       dtype='object')

# %%
sns.regplot(x='Age',y='Review Rating',data=df)
plt.ylim(0,)
# Out:
# (0.0, 5.125)

# %% [markdown]
# ### The Pearson correlation, a key method for assessing the correlation between continuous numerical variables, provides two critical values—the coefficient, which indicates the strength and direction of the correlation, and the P-value, which assesses the certainty of the correlation.
#
# ### correlation coefficient close to 1 or -1 indicates a strong positive or negative correlation, respectively, while one close to zero suggests no correlation.
#
# ### For P-values, values less than .001 indicate strong certainty in the correlation, while larger values indicate less certainty. Both the coefficient and P-value are important for confirming a strong correlation.
#
# ### Heatmaps provide a comprehensive visual summary of the strength and direction of correlations among multiple variables.

# %%
from scipy import stats
pearson_coefficent,pvalue=stats.pearsonr(df['Previous Purchases'],df['Purchase Amount (USD)'])

# %%
pearson_coefficent
# Out:
# 0.008063412270587707

# %%
pvalue
# Out:
# 0.6146783643032091

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'age bins', 'Price_bin'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
x=df[['Purchase Amount (USD)']]
y=df[ 'Review Rating']
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.predict(x)
# Out:
# array([3.74365358, 3.75389055, 3.76226625, ..., 3.72504091, 3.76598878,
#        3.76971132])

# %%
b0=lr.intercept_

# %%
b1=lr.coef_

# %% [markdown]
# Y = b0=b1*X

# %% [markdown]
# Y = b0+b1x2+b2X2+b2x3

# %%
sns.pairplot
# Out:
# <module 'seaborn' from 'C:\\Users\\DELL\\anaconda3\\Lib\\site-packages\\seaborn\\__init__.py'>
