# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data_sets',
#  'Filtering and Ordering.ipynb',
#  'Group by and Aggregating.ipynb',
#  'merge,concat,append.ipynb',
#  'Numpy,Series,DataFrames.ipynb',
#  'Untitled.ipynb']

# %%
os.listdir('./data_sets')
# Out:
# ['countries of the world.csv',
#  'Flavors.csv',
#  'Ice Cream Ratings.csv',
#  'LOTR 2.csv',
#  'LOTR.csv',
#  'world.csv']

# %%
df=pd.read_csv("./data_sets/Ice Cream Ratings.csv")

# %%
df.set_index("Date")
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot.bar(ylabel="raings",xlabel="date")
# Out:
# <Axes: xlabel='date', ylabel='raings'>

# %%
df.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.pie(y="Texture Rating")
# Out:
# <Axes: ylabel='Texture Rating'>

# %%
plt.style.use('seaborn-v0_8-whitegrid')
df.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s=40)
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>
