# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./data_sets/purchase behaviou dataset.csv')
df
# Out:
#        LYLTY_CARD_NBR       LIFESTAGE  Couples PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES  COUPLES          Premium
# 1                1002   YOUNG SINGLES  COUPLES       Mainstream
# 2                1003  YOUNG FAMILIES      NaN           Budget
# 3                1004   OLDER SINGLES  COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES  COUPLES       Mainstream
# ...               ...             ...      ...              ...
# 72632         2370651  MIDAGE SINGLES  COUPLES       Mainstream
# 72633         2370701  YOUNG FAMILIES      NaN       Mainstream
# 72634         2370751  YOUNG FAMILIES      NaN          Premium
# 72635         2370961  OLDER FAMILIES      NaN           Budget
# 72636         2373711   YOUNG SINGLES  COUPLES       Mainstream
#
# [72637 rows x 4 columns]

# %%
df['Couples'].fillna('Not couples',inplace =True)

# %%
df['Couples'] =df['Couples'].str.title()

# %%
df['LIFESTAGE']=df['LIFESTAGE'].str.title()

# %%
df.isnull().sum()
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# Couples             0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
df['LIFESTAGE'].unique()
# Out:
# array(['Young Singles', 'Young Families', 'Older Singles',
#        'Midage Singles', 'New Families', 'Older Families', 'Retirees'],
#       dtype=object)

# %%
df['PREMIUM_CUSTOMER'].unique()
# Out:
# array(['Premium', 'Mainstream', 'Budget'], dtype=object)

# %%
sns.countplot(y=df['LIFESTAGE'])
plt.grid()

# %%
df['LIFESTAGE'].value_counts()
# Out:
# LIFESTAGE
# Retirees          14805
# Older Singles     14609
# Young Singles     14441
# Older Families     9780
# Young Families     9178
# Midage Singles     7275
# New Families       2549
# Name: count, dtype: int64

# %%
crosstabs= pd.crosstab(df['LIFESTAGE'],df['PREMIUM_CUSTOMER'])

# %%
crosstabs.plot(kind='bar')
plt.grid()
plt.show()

# %%
df['PREMIUM_CUSTOMER'].value_counts().plot(kind='bar',color=['Red','green','yellow'])
plt.grid()
plt.title("Types of Subscriber's count")
plt.show()

# %%
crosstabs =pd.crosstab(df['LIFESTAGE'],df['Couples'])

# %%
crosstabs.plot(kind='bar')
plt.show()
