# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import random

# %%
os.listdir('./data_sets')
# Out:
# ['.ipynb_checkpoints',
#  'adult.csv',
#  'amazon.csv',
#  'countries of the world.csv',
#  'Customer Call List.xlsx',
#  'Ecommerce Purchases.csv',
#  'Flavors.csv',
#  'googleplaystore.csv',
#  'heart.csv',
#  'Ice Cream Ratings.csv',
#  'IMDB-Movie-Data.csv',
#  'List of the Countries and Territories.csv',
#  'LOTR 2.csv',
#  'LOTR.csv',
#  'Salaries.csv',
#  'supermarket_sales - Sheet1.csv',
#  'top-5000-youtube-channels.csv',
#  'train.csv',
#  'udemy_courses.csv',
#  'world.csv']

# %%
df=pd.read_csv('./data_sets/supermarket_sales - Sheet1.csv',parse_dates=['Date'])

# %% [markdown]
# # Attribute information
#
# #Invoice id: Computer generated sales slip invoice identification number
#
# #Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# #City: Location of supercenters
#
# #Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# #Gender: Gender type of customer
#
# #Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
# #Unit price: Price of each product in $
#
# #Quantity: Number of products purchased by customer
#
# #Tax: 5% tax fee for customer buying
#
# #Total: Total price including tax
#
# #Date: Date of purchase (Record available from January 2019 to March 2019)
#
# #Time: Purchase time (10am to 9pm)
#
# #Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# #COGS: Cost of goods sold
#
# #Gross margin percentage: Gross margin percentage
#
# #Gross income: Gross income
#
# #Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# Display top 5 rows of the dataset

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# Display last 5 rows of the dataset

# %%
df.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
# ...

# %% [markdown]
# Print Random 5 rows of dataset

# %%
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 491  510-09-5628      A     Yangon        Member  Female  Fashion accessories
# 243  217-58-1179      A     Yangon        Member    Male   Home and lifestyle
# 868  631-34-1880      C  Naypyitaw        Member    Male   Food and beverages
# 444  301-11-9629      A     Yangon        Normal  Female    Sports and travel
# 569  408-26-9866      C  Naypyitaw        Normal  Female    Sports and travel
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 491       19.66        10   9.8300  206.4300 2019-03-15  18:20  Credit card
# 243       62.65         4  12.5300  263.1300 2019-01-05  11:25         Cash
# 868       24.31         3   3.6465   76.5765 2019-01-08  19:09  Credit card
# 444       19.10         7   6.6850  140.3850 2019-01-15  10:43         Cash
# 569       73.98         7  25.8930  543.7530 2019-03-02  16:42      Ewallet
#
# ...

# %% [markdown]
#  Find shape of dataset

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# Check null values in dataset

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.isnull().any().values
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %% [markdown]
# Get info about our dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# 7) Get overall ststistics about datasets

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df.describe()
# Out:
#        Unit price  Quantity  Tax 5%   Total    cogs  gross margin percentage  \
# count     1000.00   1000.00 1000.00 1000.00 1000.00                  1000.00
# mean        55.67      5.51   15.38  322.97  307.59                     4.76
# std         26.49      2.92   11.71  245.89  234.18                     0.00
# min         10.08      1.00    0.51   10.68   10.17                     4.76
# 25%         32.88      3.00    5.92  124.42  118.50                     4.76
# 50%         55.23      5.00   12.09  253.85  241.76                     4.76
# 75%         77.94      8.00   22.45  471.35  448.91                     4.76
# max         99.96     10.00   49.65 1042.65  993.00                     4.76
#
#        gross income  Rating
# count       1000.00 1000.00
# mean          15.38    6.97
# std           11.71    1.72
# min            0.51    4.00
# 25%            5.92    5.50
# 50%           12.09    7.00
# 75%           22.45    8.50
# max           49.65   10.00

# %% [markdown]
# Univariate Analysis

# %%
cat=[]
num=[]
for x in df.columns:
    if df[x].nunique()<=10:
        cat.append(x)
    else:
        num.append(x)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# 1. Find Aggregate sales among branches(Categorical column)

# %%
sns.countplot(x='Branch',data=df)
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
df['Branch'].value_counts().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='Branch'>

# %% [markdown]
# Find the most popular payment used by customer
# (categorical column)

# %%
sns.countplot(x='Payment',data=df)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
df['Payment'].value_counts().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='Payment'>

# %% [markdown]
# 3. Find the distribution of customer Ratings(numerical column)

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.distplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %%
sns.histplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %% [markdown]
# 4.Find the distribution of cost of good sold(Numerical column)

# %%
sns.distplot(df['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
df['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(df['cogs'])
# Out:
# <Axes: >

# %% [markdown]
# # Bivariate Analysis/Multivariate Analysis

# %% [markdown]
# 1. Does the cost of goods dold affect the rating that the customer provide?(Numerical - Numerical)

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.scatterplot(x='Rating',y='cogs',data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='cogs'>

# %% [markdown]
# 2. Does Gross income affect the ratings that the customers provide?(Numerical - Numerical)

# %%
sns.scatterplot(x='Rating',y='gross income',data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='gross income'>

# %% [markdown]
#  3. find the most profitable branch as per gross income(numerical - categorical)

# %%
cat
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.barplot(x='Branch',y='gross income',data=df)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x='Branch',y='gross income',data=df,hue='City')
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# 4. is there any relationship bet2ween gender and gross income

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
sns.barplot(x='Gender',y='gross income',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x='Gender',y='gross income',data=df,hue='Customer type')
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# 5.Find the product line that generates the most income (numerical- Categorical)

# %%
df['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
sns.barplot(x='gross income',y='Product line',data=df)
# Out:
# <Axes: xlabel='gross income', ylabel='Product line'>

# %% [markdown]
# 6. Find the highest unit price in the product line(numerical-categorical)

# %%
df.groupby('Product line')['Unit price'].max()
# Out:
# Product line
# Electronic accessories   99.73
# Fashion accessories      99.89
# Food and beverages       99.79
# Health and beauty        99.96
# Home and lifestyle       99.92
# Sports and travel        99.96
# Name: Unit price, dtype: float64

# %%
sns.barplot(x='Unit price',y='Product line',data=df)
# Out:
# <Axes: xlabel='Unit price', ylabel='Product line'>

# %% [markdown]
# 7. find different payment method used by the custoomer city wise

# %%
sns.countplot(x='Payment',hue='City',data=df)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
pd.crosstab(df['Payment'],df['City'])
# Out:
# City         Mandalay  Naypyitaw  Yangon
# Payment
# Cash              110        124     110
# Credit card       109         98     104
# Ewallet           113        106     126

# %%
sns.heatmap(pd.crosstab(df['Payment'],df['City']))
# Out:
# <Axes: xlabel='City', ylabel='Payment'>

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %% [markdown]
# 8. which product line is purchased in the highest quantity?

# %%
(df.groupby('Product line')['Quantity'].sum()).plot(kind='bar',color=['red','blue','green','orange','gray','purple'])
# Out:
# <Axes: xlabel='Product line'>

# %% [markdown]
# 9. Display daily sales by day of the week

# %%
 dw_mapping ={
     0:'monday',
     1:'tuesday',
     2:'wednesday',
     3:'thursday',
     4:'friday',
     5:'saturday',
     6:'sunday'     
 }

# %%
df['day_of_week']=df['Date'].dt.dayofweek.map(dw_mapping)

# %%
(df['day_of_week'].value_counts()).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# 10. what will be the Highest Months for sales

# %%
month_dict = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}

# %%
df['day_of_month']=df['Date'].dt.month.map(month_dict)

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%   Total       Date   Time  Payment   cogs  \
# 995       40.35         1    2.02   42.37 2019-01-29  13:46  Ewallet  40.35
# 996       97.38        10   48.69 1022.49 2019-03-02  17:16  Ewallet 973.80
# 997       31.84         1    1.59   33.43 2019-02-09  13:22     Cash  31.84
# 998       65.82         1    3.29   69.11 2019-02-22  15:33     Cash  65.82
# 999       88.34         7   30.92  649.30 2019-02-18  13:28     Cash 618.38
#
# ...

# %%
(df['day_of_month'].value_counts()).plot(kind='bar')
# Out:
# <Axes: >
